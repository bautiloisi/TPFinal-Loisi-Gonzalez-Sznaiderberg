# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
# Directorios para datos de entrenamiento, prueba y validación
train_data_dir = '/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Train'
test_data_dir = '/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Test'
validation_data_dir = '/kaggle/input/face-mask-12k-images-dataset/Face Mask Dataset/Validation'

# Configurar generadores de imágenes para entrenamiento, prueba y validación
train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# Configurar generadores de datos para entrenamiento, prueba y validación
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'  # Para clasificación binaria, ajusta según el número de clases
)

test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(128, 128),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 10000 images belonging to 2 classes.
# Found 992 images belonging to 2 classes.
# Found 800 images belonging to 2 classes.

# %%
# Definir el modelo de la CNN
model = Sequential()

# Capa de convolución 1
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D((2, 2)))

# Capa de convolución 2
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Capa de convolución 3
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D((2, 2)))

# Capa completamente conectada
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))  # Dropout para reducir el sobreajuste
model.add(Dense(1, activation='sigmoid'))  # 1 neurona para la clasificación binaria

# Compilar el modelo
model.compile(optimizer=Adam(lr=0.0001), loss='binary_crossentropy', metrics=['accuracy'])

# Entrenar el modelo usando el generador de datos
history = model.fit(
    train_generator,
    steps_per_epoch=len(train_generator),
    epochs=10,
    validation_data=validation_generator,
    validation_steps=len(validation_generator)
)
# Out:
# Epoch 1/10
# 313/313 [==============================] - 238s 753ms/step - loss: 0.1416 - accuracy: 0.9468 - val_loss: 0.0298 - val_accuracy: 0.9912
# Epoch 2/10
# 313/313 [==============================] - 223s 712ms/step - loss: 0.0569 - accuracy: 0.9798 - val_loss: 0.0260 - val_accuracy: 0.9862
# Epoch 3/10
# 313/313 [==============================] - 222s 708ms/step - loss: 0.0478 - accuracy: 0.9828 - val_loss: 0.0128 - val_accuracy: 0.9937
# Epoch 4/10
# 313/313 [==============================] - 221s 706ms/step - loss: 0.0417 - accuracy: 0.9857 - val_loss: 0.0135 - val_accuracy: 0.9937
# Epoch 5/10
# 313/313 [==============================] - 221s 707ms/step - loss: 0.0349 - accuracy: 0.9878 - val_loss: 0.0137 - val_accuracy: 0.9962
# Epoch 6/10
# 313/313 [==============================] - 221s 706ms/step - loss: 0.0293 - accuracy: 0.9893 - val_loss: 0.0190 - val_accuracy: 0.9925
# Epoch 7/10
# 313/313 [==============================] - 220s 703ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.0091 - val_accuracy: 0.9962
# Epoch 8/10
# 313/313 [==============================] - 219s 700ms/step - loss: 0.0243 - accuracy: 0.9915 - val_loss: 0.0265 - val_accuracy: 0.9887
# Epoch 9/10
# 313/313 [==============================] - 217s 694ms/step - loss: 0.0304 - accuracy: 0.9901 - val_loss: 0.0368 - val_accuracy: 0.9825
# Epoch 10/10
# 313/313 [==============================] - 219s 700ms/step - loss: 0.0283 - accuracy: 0.9896 - val_loss: 0.0335 - val_accuracy: 0.9862

# %%
model.save("model.h5")

# %%
from IPython.display import FileLink, display

# %%
display(FileLink(f'model.h5'))
# Out:
# /kaggle/working/model.h5
# /kaggle/working/model.h5
